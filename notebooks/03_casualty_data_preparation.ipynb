# %% [markdown]
# Casualty Data Preparation
#
# Project Objective
#
# This notebook prepares the official UK Department for Transport casualty dataset for the machine learning project.
#
# The main objectives are:
#
# - Load the casualty dataset.
# - Keep only casualties involved in collisions from 2010 onwards.
# - Explore the dataset structure.
# - Assess data quality.
# - Remove unnecessary variables.
# - Prepare a clean dataset for the data integration stage.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Dataset
#
# Load the cleaned collision dataset together with the official casualty dataset.
#
# Only casualties associated with collisions from 2010 onwards are retained to ensure consistency across the project.

# %%
collision = pd.read_csv('/content/drive/MyDrive/PROYECT_1/collision_clean.csv')

# %%
valid_collision_ids = set(collision['collision_index'])

# %%
df = pd.read_csv('/content/drive/MyDrive/PROYECT_1/dft-road-casualty-statistics-casualty-1979-latest-published-year.csv')
# Out:
# /tmp/ipykernel_6317/3641707412.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/PROYECT_1/dft-road-casualty-statistics-casualty-1979-latest-published-year.csv')

# %%
df = df[df['collision_index'].isin(valid_collision_ids)].copy()

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Exploration and Data Cleaning

# %%
df.head()
# Out:
#        collision_index  collision_year collision_ref_no  vehicle_reference  \
# 158700   201014A106410            2010        14A106410                  1
# 158701   2010331003800            2010        331003800                  2
# 158702   2010521008537            2010        521008537                  1
# 158703   201043W163070            2010        43W163070                  2
# 158704   2010521009474            2010        521009474                  1
#
#         casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 158700                   1               3                1                8
# 158701                   1               1                1               12
# 158702                   1               1                2               55
# 158703                   1               1                2               19
# 158704                   1               1                2               38
#
# ...

# %%
df.shape
# Out:
# (2479311, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2479311 entries, 158700 to 11974249
# Data columns (total 23 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   collision_index                     object
#  1   collision_year                      int64
#  2   collision_ref_no                    object
#  3   vehicle_reference                   int64
#  4   casualty_reference                  int64
#  5   casualty_class                      int64
#  6   sex_of_casualty                     int64
#  7   age_of_casualty                     int64
#  8   age_band_of_casualty                int64
#  9   casualty_severity                   int64
#  10  pedestrian_location                 int64
#  11  pedestrian_movement                 int64
#  12  car_passenger                       int64
#  13  bus_or_coach_passenger              int64
#  14  pedestrian_road_maintenance_worker  int64
# ...

# %%
df.isnull().sum()
# Out:
# collision_index                       0
# collision_year                        0
# collision_ref_no                      0
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# age_band_of_casualty                  0
# casualty_severity                     0
# pedestrian_location                   0
# pedestrian_movement                   0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_imd_decile                   0
# lsoa_of_casualty                      0
# enhanced_casualty_severity            0
# casualty_injury_based                 0
# casualty_adjusted_severity_serious    0
# casualty_adjusted_severity_slight     0
# casualty_distance_banding             0
# dtype: int64

# %%
df.describe()
# Out:
#        collision_year  vehicle_reference  casualty_reference  casualty_class  \
# count    2.479311e+06       2.479311e+06        2.479311e+06    2.479311e+06
# mean     2.016260e+03       1.479008e+00        1.401705e+00    1.485361e+00
# std      4.262213e+00       1.554960e+00        2.037326e+00    7.187896e-01
# min      2.010000e+03       1.000000e+00        1.000000e+00    1.000000e+00
# 25%      2.013000e+03       1.000000e+00        1.000000e+00    1.000000e+00
# 50%      2.016000e+03       1.000000e+00        1.000000e+00    1.000000e+00
# 75%      2.020000e+03       2.000000e+00        1.000000e+00    2.000000e+00
# max      2.024000e+03       9.990000e+02        9.990000e+02    3.000000e+00
#
#        sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count     2.479311e+06     2.479311e+06          2.479311e+06
# mean      1.396801e+00     3.616866e+01          6.243758e+00
# std       5.076927e-01     1.930900e+01          2.415672e+00
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# collision_index                       1886746
# collision_year                             15
# collision_ref_no                      1655485
# vehicle_reference                          80
# casualty_reference                        107
# casualty_class                              3
# sex_of_casualty                             4
# age_of_casualty                           106
# age_band_of_casualty                       12
# casualty_severity                           3
# pedestrian_location                        12
# pedestrian_movement                        11
# car_passenger                               5
# bus_or_coach_passenger                      7
# pedestrian_road_maintenance_worker          5
# casualty_type                              23
# casualty_imd_decile                        11
# lsoa_of_casualty                        37356
# enhanced_casualty_severity                  6
# casualty_injury_based                       2
# ...

# %%
columns_to_drop = [

    "collision_ref_no",

    "enhanced_casualty_severity",

    "casualty_injury_based",

    "casualty_adjusted_severity_serious",

    "casualty_adjusted_severity_slight"

]

# %%
df.drop(columns=columns_to_drop,axis=1, inplace=True)

# %% [markdown]
# Save Clean Dataset
#
# Export the cleaned casualty dataset.
#
# The resulting dataset will be combined with the collision and vehicle datasets during the data integration stage.

# %%
df.to_csv('casualty_clean.csv',index=False)

# %% [markdown]
# The casualty dataset was successfully prepared for the next stage of the project.
#
# Summary of the work completed:
#
# - Filtered the dataset to include only casualties involved in collisions from 2010 onwards.
# - Assessed the overall quality of the data.
# - Verified that no duplicate records were present.
# - Confirmed that no missing values required treatment.
# - Removed redundant identifier variables.
# - Removed variables that could introduce data leakage into the machine learning model.
# - Exported a clean dataset ready for data integration.

# %%
print('Casualty Dataset Summary')
print('='*50)
print(f'Rows: {df.shape[0]}')
print(f'Columns: {df.shape[1]}')
print(f'Missing Values: {df.isnull().sum().sum()}')
print(f'Duplicate Rows: {df.duplicated().sum()}')
# Out:
# Casualty Dataset Summary
# ...
# Rows: 2479311
# Columns: 18
# Missing Values: 0
# Duplicate Rows: 0
